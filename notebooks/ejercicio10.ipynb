# %%
import sys      

sys.path.append('..')

from src.competencia import rounds, procesar_competencia

resultados = procesar_competencia (rounds)
# Out:
# Ronda 1 - Entrada
# Ganador de la ronda: Camila con 26 puntos
# ------------------------------
# ---Tabla parcial---
# Valentina - Puntos: 24 puntos.
# Mateo - Puntos: 22 puntos.
# Camila - Puntos: 26 puntos.
# Santiago - Puntos: 19 puntos.
# Lucía - Puntos: 24 puntos.
#
#
# Ronda 2 - Plato principal
# Ganador de la ronda: Valentina con 26 puntos
# ------------------------------
# ---Tabla parcial---
# Valentina - Puntos: 50 puntos.
# Mateo - Puntos: 46 puntos.
# Camila - Puntos: 46 puntos.
# Santiago - Puntos: 44 puntos.
# Lucía - Puntos: 46 puntos.
#
#
# Ronda 3 - Postre
# Ganador de la ronda: Lucía con 27 puntos
# ------------------------------
# ---Tabla parcial---
# Valentina - Puntos: 72 puntos.
# Mateo - Puntos: 72 puntos.
# Camila - Puntos: 70 puntos.
# Santiago - Puntos: 64 puntos.
# Lucía - Puntos: 73 puntos.
#
#
# Ronda 4 - Cocina internacional
# Ganador de la ronda: Valentina con 26 puntos
# ------------------------------
# ---Tabla parcial---
# ...
